# %% [markdown]
# #CRM Coursework

# %%
#1A

import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import pandas_datareader as dr

import requests
sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

r = requests.get(sp500_url, headers=header)

data_table = pd.read_html(r.text)[1]
# Out:
# /tmp/ipython-input-2647639506.py:18: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   data_table = pd.read_html(r.text)[1]

# %%
#Data table
data_table
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
#1B

import yfinance as yf
# !pip install yahoofinancials
from yahoofinancials import YahooFinancials
from datetime import datetime

start = '2022-01-01'
end = '2025-01-01'

Data_stock_price = yf.download(data_table['Symbol'].values.tolist(), start= start , end = end)
# Out:
# ...
# /tmp/ipython-input-2178762820.py:11: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   Data_stock_price = yf.download(data_table['Symbol'].values.tolist(), start= start , end = end)
# [*********************100%***********************]  503 of 503 completed
# ERROR:yfinance:
# 4 Failed downloads:
# ERROR:yfinance:['Q', 'SOLS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2022-01-01 -> 2025-01-01) (Yahoo error = "Data doesn\'t exist for startDate = 1641013200, endDate = 1735707600")')
# ERROR:yfinance:['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['BF.B']: YFPricesMissingError('possibly delisted; no price data found  (1d 2022-01-01 -> 2025-01-01)')

# %%
#Data Stock Price
Data_stock_price
# Out:
# Price      Adj Close                      Close                          \
# Ticker          BF.B BRK.B   Q SOLS           A        AAPL        ABBV
# Date
# 2022-01-03       NaN   NaN NaN  NaN  152.320023  178.270309  116.779297
# 2022-01-04       NaN   NaN NaN  NaN  147.170700  176.007782  116.555107
# 2022-01-05       NaN   NaN NaN  NaN  144.649551  171.326004  117.167366
# 2022-01-06       NaN   NaN NaN  NaN  145.155731  168.465973  116.615440
# 2022-01-07       NaN   NaN NaN  NaN  141.291229  168.632477  116.313637
# ...              ...   ...  ..  ...         ...         ...         ...
# 2024-12-24       NaN   NaN NaN  NaN  135.004929  257.037476  173.918823
# 2024-12-26       NaN   NaN NaN  NaN  134.737091  257.853760  173.145828
# 2024-12-27       NaN   NaN NaN  NaN  134.449417  254.439209  171.996017
# 2024-12-30       NaN   NaN NaN  NaN  133.338440  251.064484  170.247192
# 2024-12-31       NaN   NaN NaN  NaN  133.505386  249.292511  171.696503
#
# ...

# %%
#1C
# Remove invalid data
Data_stock_price = Data_stock_price.dropna(how='all')
data_table
# Out:
#     Symbol             Security             GICS Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
#2A
import math
daily_returns = Data_stock_price['Close'].pct_change(fill_method=None)
daily_returns
# Out:
# Ticker             A      AAPL      ABBV      ABNB       ABT      ACGL  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.033806 -0.012692 -0.001920 -0.010887 -0.023518  0.013019
# 2022-01-05 -0.017131 -0.026600  0.005253 -0.050059 -0.004493 -0.011744
# 2022-01-06  0.003499 -0.016694 -0.004711 -0.015408 -0.000148  0.005830
# 2022-01-07 -0.026623  0.000988 -0.002588  0.039437  0.003108  0.004681
# ...              ...       ...       ...       ...       ...       ...
# 2024-12-24  0.011144  0.011478  0.009025  0.003494  0.003937  0.006298
# 2024-12-26 -0.001984  0.003176 -0.004445  0.002445  0.004444  0.002806
# 2024-12-27 -0.002135 -0.013242 -0.006641 -0.014300 -0.002429 -0.006349
# 2024-12-30 -0.008263 -0.013263 -0.010168 -0.011808 -0.019045 -0.004873
# 2024-12-31  0.001252 -0.007058  0.008513 -0.003035  0.002748  0.005006
#
# Ticker           ACN      ADBE       ADI       ADM  ...        WY      WYNN  \
# ...

# %%
import yfinance as yf
import pandas as pd


def calculate_betas(markets, stocks, start_date, end_date):

  market = yf.download(markets, start_date, end_date)
  market['stock_name'] = markets

  market['daily_return'] = market['Close'].pct_change(1)

  market_std = market['daily_return'].std()
  market.dropna(inplace=True)
  market = market[['Close', 'stock_name', 'daily_return']]

  frames = []
  stds = []
  for i in stocks:
    data = yf.download(i, start_date, end_date)
    data['stock_name'] = i
    data['daily_return'] = data['Close'].pct_change(1)
    data.dropna(inplace=True)
    data = data[[ 'Close', 'stock_name', 'daily_return']]
    data_std = data['daily_return'].std()
    frames.append(data)
    stds.append(data_std)

  stock_correlation = []
  for i in frames:
    correlation = i['daily_return'].corr(market['daily_return'])
    stock_correlation.append(correlation)

  betas = []
  for b,i in zip(stock_correlation, stds):
    beta_calc = b * (i/market_std)
    betas.append(beta_calc)

  dictionary = {stocks[e]: betas[e] for e in range(len(stocks))}
  dataframe = pd.DataFrame([dictionary]).T
  dataframe.reset_index(inplace=True)
  dataframe.rename(
    columns={"index": "Stock_Name", 0: "Beta"},
    inplace=True,)
  return dataframe

# %%
beta_df = calculate_betas('^GSPC', data_table['Symbol'], '2022-01-01', '2025-01-01')
# Out:
# /tmp/ipython-input-1338782279.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   market = yf.download(markets, start_date, end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-1338782279.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(i, start_date, end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-1338782279.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(i, start_date, end_date)
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipython-input-1338782279.py:19: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(i, start_date, end_date)
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
#2C
import math
annual_volatility = daily_returns.std() * math.sqrt(252)
vol_table = annual_volatility.reset_index()
vol_table.columns = ['Stock_Name', 'Annual_Volatility']
vol_table
# Out:
#     Stock_Name  Annual_Volatility
# 0            A           0.296259
# 1         AAPL           0.270935
# 2         ABBV           0.219958
# 3         ABNB           0.467875
# 4          ABT           0.217839
# ..         ...                ...
# 498        XYZ           0.653825
# 499        YUM           0.191335
# 500        ZBH           0.245157
# 501       ZBRA           0.400050
# 502        ZTS           0.275016
#
# [503 rows x 2 columns]

# %%
# --- Task 3A: Silhouette Score vs Number of Clusters ---

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
import numpy as np

# Extract Beta values as a 2-D array
beta_values = betas_table['Beta'].dropna().values.reshape(-1, 1)

# Test K values
k_values = [2, 3, 4, 5, 6, 7, 8, 9]
scores = []

for k in k_values:
    model = AgglomerativeClustering(n_clusters=k)
    labels = model.fit_predict(beta_values)
    score = silhouette_score(beta_values, labels)
    scores.append(score)

# Plot silhouette scores
plt.figure(figsize=(10, 6))
plt.plot(k_values, scores, marker='o')
plt.title("Silhouette Score vs. Number of Clusters (K)")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Silhouette Score")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
#3B dendogram
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# get the beta values from the earlier step
beta_values = beta_df[['Beta']].copy()

# make sure there are no missing or infinite values
beta_values = beta_values.replace([np.inf, -np.inf], np.nan)
beta_values = beta_values.dropna()

# convert the beta column into a numpy array (required by linkage)
beta_array = beta_values.values

link_matrix = linkage(beta_array, method='ward')

plt.figure(figsize=(16, 7), dpi=150)

dendrogram(
    link_matrix,
    truncate_mode='lastp',
    p=30,
    leaf_rotation=90,
    leaf_font_size=10,
    show_contracted=True
)

plt.title("Hierarchical Clustering Dendrogram - Beta Values (Full Dataset)", fontsize=14)
plt.xlabel("Cluster Size (or Index)", fontsize=12)
plt.ylabel("Distance (Ward Linkage)", fontsize=12)

plt.axhline(y=3, color='red', linestyle='--', label='Potential cut for 3 clusters')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import AgglomerativeClustering

beta_clean = beta_df.copy()
beta_clean['Beta'] = pd.to_numeric(beta_clean['Beta'], errors='coerce')

beta_clean = beta_clean.replace([np.inf, -np.inf], np.nan)
beta_clean = beta_clean.dropna(subset=['Beta'])

print("Rows in cleaned beta_df:", len(beta_clean))

best_k = 3


agg = AgglomerativeClustering(n_clusters=best_k)
beta_clean['Cluster'] = agg.fit_predict(beta_clean[['Beta']])

clustered_beta = beta_clean[['Stock_Name', 'Beta', 'Cluster']]

clustered_beta.head(10)
# Out:
# Rows in cleaned beta_df: 499
#   Stock_Name      Beta  Cluster
# 0        MMM  0.783736        0
# 1        AOS  0.924451        2
# 2        ABT  0.672317        0
# 3       ABBV  0.299098        0
# 4        ACN  1.094207        2
# 5       ADBE  1.447974        1
# 6        AMD  2.064749        1
# 7        AES  1.015896        2
# 8        AFL  0.607780        0
# 9          A  1.024800        2

# %%
#3C

import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
import numpy as np

beta_clean = beta_df[['Beta']].replace([np.inf, -np.inf], np.nan).dropna()
beta_clean = beta_clean.reset_index(drop=True)

beta_array = beta_clean.values


k_values = [2, 3, 4, 5, 6, 7, 8, 9]

plt.figure(figsize=(18, 18))

for idx, k in enumerate(k_values, 1):


    model = AgglomerativeClustering(n_clusters=k)
    labels = model.fit_predict(beta_array)

    plt.subplot(3, 3, idx)
    plt.scatter(beta_clean['Beta'], range(len(beta_clean)), c=labels, cmap='tab10', s=10)

    plt.title(f"n_clusters = {k}")
    plt.xlabel("Beta")
    plt.ylabel("Index")

    plt.grid(alpha=0.3, linestyle='--')

plt.tight_layout()
plt.show()

# %%
#4B

import pandas as pd
from sklearn.cluster import AgglomerativeClustering

X = beta_table[['Beta']].fillna(beta_table['Beta'].mean()).values.reshape(-1, 1)

model = AgglomerativeClustering(n_clusters=3)
labels = model.fit_predict(X)

beta_table['Cluster'] = labels

beta_sorted = beta_table.sort_values(by='Cluster')

print("Full Cluster Assignment Table:")
display(beta_sorted)

print("\nMean Beta for each cluster:")
display(beta_sorted.groupby('Cluster')['Beta'].mean())

print("\nNumber of stocks in each cluster:")
display(beta_sorted['Cluster'].value_counts().sort_index())
# Out:
# Full Cluster Assignment Table:
#   Stock_Name      Beta  Cluster
# 2       TSLA  1.736488        0
# 1       MSFT  1.284474        1
# 0       AAPL  1.305798        2
# Mean Beta for each cluster:
# Cluster
# 0    1.736488
# 1    1.284474
# 2    1.305798
# Name: Beta, dtype: float64
# Number of stocks in each cluster:
# Cluster
# 0    1
# 1    1
# 2    1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# ---- Load FULL beta column ----
x = betas_df[['Beta']].dropna()  # your full 503 rows
x_array = x.values.reshape(-1, 1)

# ---- Scale the data ----
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_array)

# ---- Elbow method ----
k_values = range(2, 11)
inertias = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(x_scaled)
    inertias.append(kmeans.inertia_)

# ---- Plot ----
plt.figure(figsize=(10, 6))
plt.plot(k_values, inertias, marker='o')
plt.title("Elbow Method for K-Means (Scaled Beta Values)")
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia (Within-Cluster SS)")
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
#4C
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# 1. Merge beta and volatility tables
df_kmeans = pd.merge(beta_df, vol_table, on='Stock_Name', how='inner')

# 2. Drop missing values
df_kmeans = df_kmeans.dropna(subset=['Beta', 'Annual_Volatility'])

# 3. Select features
X = df_kmeans[['Beta', 'Annual_Volatility']]

# 4. Scale (important!)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 5. K-Means with K = 4
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df_kmeans['KMeans_Cluster'] = kmeans.fit_predict(X_scaled)

# 6. Plot scatter
plt.figure(figsize=(12, 7))
sns.scatterplot(
    x='Beta',
    y='Annual_Volatility',
    hue='KMeans_Cluster',
    palette='viridis',
    data=df_kmeans,
    s=40,
    alpha=0.9
)

plt.title("K-Means Clustering of Stocks (K = 3)")
plt.xlabel("Beta")
plt.ylabel("Annual Volatility")
plt.grid(alpha=0.3)
plt.legend(title="KMeans_Cluster")
plt.show()

# %%
# --- Task 5B: K-Means Clustering Plot with Market Beta Line ---

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 7))

# Scatter plot: Beta vs Annual Volatility
sns.scatterplot(
    data=df_kmeans,
    x='Beta',
    y='Annual_Volatility',
    hue='KMeans_Cluster',
    palette='viridis',
    s=40,
    alpha=0.9
)

# Add vertical line at Market Beta = 1
plt.axvline(x=1.0, color='red', linestyle='--', linewidth=1.5, label='Market Beta = 1')

# Title + Labels
plt.title("Stock Clusters by Risk (K-Means K = 3)", fontsize=16)
plt.xlabel("Beta", fontsize=13)
plt.ylabel("Annual Volatility", fontsize=13)

# Legend
plt.legend(title="K-Means Cluster")
plt.grid(alpha=0.3)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Compute Daily Returns from Volatility ---
# Convert annual volatility to daily (approx formula)
df_kmeans["Daily_Return"] = df_kmeans["Annual_Volatility"] / np.sqrt(252)

# --- 2. Compute averages per cluster ---
beta_means = df_kmeans.groupby("KMeans_Cluster")["Beta"].mean()
vol_means = df_kmeans.groupby("KMeans_Cluster")["Annual_Volatility"].mean()
return_means = df_kmeans.groupby("KMeans_Cluster")["Daily_Return"].mean()

# Ensure clusters appear as 0,1,2,3 (even if some missing)
clusters = sorted(df_kmeans["KMeans_Cluster"].unique())

# --- 3. Plot grouped bar chart ---
x = np.arange(len(clusters))
width = 0.25

plt.figure(figsize=(12, 6))

plt.bar(x - width, beta_means.values, width, label="Beta")
plt.bar(x, vol_means.values, width, label="Annual Volatility")
plt.bar(x + width, return_means.values, width, label="Daily Return")

plt.xlabel("Cluster")
plt.ylabel("Average")
plt.title("Comparing Beta, Annual Volatility, and Daily Return per Cluster")

plt.xticks(x, clusters)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.3)

plt.show()
